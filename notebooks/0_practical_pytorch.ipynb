# %% [markdown]
# # Practical PyTorch

# %% [markdown]
# <a href="https://colab.research.google.com/github/Paulescu/practical-nlp-2021/blob/main/notebooks/X.%20Fine-tune%20BERT%20for%20sentence%20classification.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab" align="left"/>
# </a>

# %% [markdown]
# ## Goal
# This notebooks shows the basic elements you need to quickly start building and training your models with PyTorch.
#
# ## Intended audience
#
# Data scientits/Machine Learning engineers who have some experience training ML models with other Python libraries (scikit-learn, Tensorflow), and who would like to quickly be productive using PyTorch.
#
# We follow a [top-down approach](https://en.wikipedia.org/wiki/Top-down_and_bottom-up_design), where we first identify the main components you need to have in place to train your ML model and then we start getting into the PyTorch specifics. This learning approach, I believe, is more effective than a bottom-up, where you start learning language primitives (e.g. torch.Tensor) and then add each of the components you need, one at a time.

# %%
from IPython.display import Image
Image(filename='images/ml_train_basic_elements.png')

# %% [markdown]
# ## Sections

# %% [markdown]
# ## 0. How to create an amazin PyTorch model architecture

# %% [markdown]
# ## 1. How to load your data into the model architecture
